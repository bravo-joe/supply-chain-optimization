# %%
# Beginning of "eda.ipynb"

# %% [markdown]
# # Exploratory Data Analysis
#
# The following is the data analysis done after the first part of the project which was to create synthetic data that represents a transportation problem. Want to explore the results of said dataset.

# %%
# Import necessary libraries and modules
import yaml # Read config files
import pandas as pd
pd.set_option('display.max_rows', 12)
pd.set_option('display.max_columns', 10)
import sys
sys.path.insert(0, "..")

from helper_funcs import query_tbl

# %% [markdown]
# ## Section 1: Query Data from Database
# ### Establish a database connection using SQLAlchemy
#
# Have the logic in a new helper function script that will be included in the project.

# %%
df = query_tbl("../config.yaml")
# Out:
# Table successfully read from PostgreSQL!
# Read time: 0.180 seconds

# %%
# To see the demand
df.tail(15)
# To see production capacity
# df.head(15)
# Out:
#          index  customer_1  customer_2  customer_3  customer_4  ...  \
# 61  factory_62           3           6           3           9  ...
# 62  factory_63           9           2           2           5  ...
# 63  factory_64           9          12          15           4  ...
# 64  factory_65           6           9          11          14  ...
# 65  factory_66          12          14           2          10  ...
# ..         ...         ...         ...         ...         ...  ...
# 71  factory_72           6          13           8           4  ...
# 72  factory_73           6          11          11           3  ...
# 73  factory_74           1           3          14          11  ...
# 74  factory_75           6          15           6           6  ...
# 75      demand         200          60         230         280  ...
#
#     customer_122  customer_123  customer_124  customer_125  \
# 61            14             6             5             7
# 62            15             1             8             1
# 63             7             5             2             1
# 64             7             9             5             7
# 65             1             9            14             6
# ..           ...           ...           ...           ...
# 71             6             3             4             3
# 72             7             2             1            11
# 73             3             7             4             4
# 74            12            10             3             5
# 75            80           220           220            80
#
#     production_capacity
# 61                750.0
# 62                375.0
# 63                375.0
# 64                500.0
# 65                750.0
# ..                  ...
# 71                500.0
# 72                125.0
# 73                750.0
# 74                500.0
# 75                  NaN
#
# [15 rows x 127 columns]

# %% [markdown]
# Want a subset that removes the final row and column which is the demand and production capacity, respectively.

# %%
trans_costs = df.iloc[:-1, 1:-1]
trans_costs.head(15)
# Out:
#     customer_1  customer_2  customer_3  customer_4  customer_5  ...  \
# 0           15          12          13           2          13  ...
# 1            1           5           5          14           2  ...
# 2           15          14          12           2           6  ...
# 3           14           7          10          13           5  ...
# 4           12           5           4           9           1  ...
# ..         ...         ...         ...         ...         ...  ...
# 10           9          12          15          10           8  ...
# 11          13           9           1           6           5  ...
# 12           8          13           3           8          12  ...
# 13          14          10           8          15           1  ...
# 14          14           8          10          15           5  ...
#
#     customer_121  customer_122  customer_123  customer_124  customer_125
# 0             13            11             8             7            11
# 1             14            11             1            11             8
# 2              4             4             6            12             5
# 3              2             8             5             8            14
# 4              6             2            15             5             7
# ..           ...           ...           ...           ...           ...
# 10            15             9             6             9             9
# 11            14            10             4             3             4
# 12             8             6            10            14            15
# 13             6             2            12            14             5
# 14             2            10            12             3             5
#
# [15 rows x 125 columns]

# %% [markdown]
# ## Section 2: Metrics for the Dashboard
# Want to gather the number of customers and number of factories.

# %%
num_of_plants = len(trans_costs.index)
print(f"The number of factories: {num_of_plants}")
# Out:
# The number of factories: 75

# %%
# Get the number of plants
num_of_customers = len(trans_costs.columns)
print(f"The number of customers: {num_of_customers}")
# Out:
# The number of customers: 125

# %% [markdown]
# Wanted a random subset of 15 customers to perform some analysis.

# %%
# Randomly select 15 columns
n_cols = 15
df2 = trans_costs.sample(
    n = n_cols,
    axis = 1
)
df2
# Out:
#     customer_53  customer_11  customer_15  customer_19  customer_61  ...  \
# 0             3            4            6            8           11  ...
# 1            12            9           14            2           13  ...
# 2             2            6            5            5            7  ...
# 3            13           12            4            6           10  ...
# 4             6            5            7            6            6  ...
# ..          ...          ...          ...          ...          ...  ...
# 70            3           15           11           13            2  ...
# 71            6            3            4            1           15  ...
# 72           10           11            1           15            6  ...
# 73            2            3           10           11            8  ...
# 74           12           10            7           14            9  ...
#
#     customer_55  customer_10  customer_96  customer_46  customer_31
# 0            15            6            5            9            8
# 1             6            2            1            8            6
# 2            11            1           14            8           11
# 3             5           13            8            3            3
# 4            10           15            5            6            8
# ..          ...          ...          ...          ...          ...
# 70            2            9            1            3            9
# 71            9           13           11            4            3
# 72           14            9            4            7            1
# 73           15            1            7            1           10
# 74           11           15            3           13            6
#
# [75 rows x 15 columns]

# %% [markdown]
# ## Section 3: Plotting EDA

# %%
import matplotlib.pyplot as plt
df2.boxplot()
ax = plt.subplot()
ax.set_ylabel("Transportation Costs ($)")
# Hide grid lines
plt.grid(False)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Now, want to recreate the same plot using the `plotnine` library. Will be using this library for the dashboard I am creating.

# %%
from plotnine import (
    ggplot,
    aes,
    geom_boxplot,
    scale_x_discrete,
    labs,
    coord_flip,
    geom_histogram,
    theme,
    element_text
)

# %% [markdown]
# Melt the second data frame to get customers as values and their transportation cost as the other column. Easier for plotting in ggplot with Python

# %%
df3 = df2.melt()
df3
# Out:
#          variable  value
# 0     customer_53      3
# 1     customer_53     12
# 2     customer_53      2
# 3     customer_53     13
# 4     customer_53      6
# ...           ...    ...
# 1120  customer_31      9
# 1121  customer_31      3
# 1122  customer_31      1
# 1123  customer_31     10
# 1124  customer_31      6
#
# [1125 rows x 2 columns]

# %%
# Plotting Logic
(
    ggplot(df3)
    + aes(
        x="variable",
        y="value"
        ) 
    + scale_x_discrete(
        name="Customers"
        )
    + labs(
        title="Sample of Customers",
        y="Transportation Costs ($)"
        )
    + geom_boxplot(
        colour="#1F3552",
        fill="#4271AE"
        )
    + coord_flip()
)

# %%
df2.head()
# Out:
#    customer_53  customer_11  customer_15  customer_19  customer_61  ...  \
# 0            3            4            6            8           11  ...
# 1           12            9           14            2           13  ...
# 2            2            6            5            5            7  ...
# 3           13           12            4            6           10  ...
# 4            6            5            7            6            6  ...
#
#    customer_55  customer_10  customer_96  customer_46  customer_31
# 0           15            6            5            9            8
# 1            6            2            1            8            6
# 2           11            1           14            8           11
# 3            5           13            8            3            3
# 4           10           15            5            6            8
#
# [5 rows x 15 columns]

# %%
trans_costs.mean()
# Out:
# customer_1      9.173333
# customer_2      8.000000
# customer_3      8.266667
# customer_4      7.013333
# customer_5      7.026667
#                   ...
# customer_121    7.400000
# customer_122    8.120000
# customer_123    7.506667
# customer_124    7.853333
# customer_125    6.440000
# Length: 125, dtype: float64

# %% [markdown]
# Will extract the demand and production capacity as Pandas Dataframe to get an instagram.

# %%
# Extract the demand row into its own Pandas Series
# demand = df.iloc[:,-1]
demand = df.iloc[-1,:]
type(demand)
# Out:
# pandas.core.series.Series

# %%
# Convert from series to dataframe
demand = demand.to_frame(name = 'demand')
demand
# Out:
#                      demand
# index                demand
# customer_1              200
# customer_2               60
# customer_3              230
# customer_4              280
# ...                     ...
# customer_122             80
# customer_123            220
# customer_124            220
# customer_125             80
# production_capacity     NaN
#
# [127 rows x 1 columns]

# %%
# Drop NAs from the dataframe
demand = demand.dropna()
# demand.drop(demand.iloc[0], axis=0)
demand
# Out:
#               demand
# index         demand
# customer_1       200
# customer_2        60
# customer_3       230
# customer_4       280
# ...              ...
# customer_121     280
# customer_122      80
# customer_123     220
# customer_124     220
# customer_125      80
#
# [126 rows x 1 columns]

# %%
demand = demand.iloc[1:, :]

# %%
demand
# Out:
#              demand
# customer_1      200
# customer_2       60
# customer_3      230
# customer_4      280
# customer_5       90
# ...             ...
# customer_121    280
# customer_122     80
# customer_123    220
# customer_124    220
# customer_125     80
#
# [125 rows x 1 columns]

# %%
demand = demand.reset_index()
demand = demand.drop(labels="index", axis=1)
demand
# Out:
#     demand
# 0      200
# 1       60
# 2      230
# 3      280
# 4       90
# ..     ...
# 120    280
# 121     80
# 122    220
# 123    220
# 124     80
#
# [125 rows x 1 columns]

# %%
print(f"The average demand (units) per customer: {demand.mean()}")
# Out:
# The average demand (units) per customer: demand    183.92
# dtype: object

# %% [markdown]
# Going to comment-out the following blocks/cells of code. Some of the logic applied to the demand as a Series, that is, before converting it to a Dataframe. And second cell has plotting logic but only for `matplotlib` and didn't feel an urgency to update it because we're working with ggplot (plotnine) now.

# %%
# Resetting the index
# demand = demand.reset_index()
# demand = demand.iloc[:,-1]
# demand.columns = demand.iloc[0]
# print(demand.shape)
# print(demand)

# %% [markdown]
# Now, want to create a histogram from the Pandas Series.

# %%
# # For density histogram
# # demand.plot(kind='hist', density=True)
# demand.plot(kind='hist', color = 'green', edgecolor='black', bins=10)
# plt.show()

# %% [markdown]
# Create the same histogram but using ggplot.

# %%
# Plotting Logic
(
    ggplot(
        demand
        )
    + aes(
        x='demand'
        )
    + geom_histogram(
        bins=10,
        fill='#5cb5d3',
        color='#040e05'
        )
    + labs(
        title="Distribution of Demand",
        x="Demand (units)",
        y="Count (unitless)"
        )
    + theme(
        axis_text_x=element_text(
            rotation=90,
            hjust=1
            )
        )
)

# %%
# Pull the last column which is the production capacity
prod_cap = df.iloc[:,-1]
# Remove NA's
prod_cap = prod_cap.dropna()
# Turn data type from float to integer
prod_cap = prod_cap.astype(int)
# Convert from series to dataframe
prod_cap = prod_cap.to_frame(name = 'production_capacity')
print(prod_cap)
# Out:
#     production_capacity
# 0                   625
# 1                   250
# 2                   375
# 3                   625
# 4                   125
# ..                  ...
# 70                  375
# 71                  500
# 72                  125
# 73                  750
# 74                  500
#
# [75 rows x 1 columns]

# %%
type(prod_cap)
# Out:
# pandas.core.frame.DataFrame

# %%
print(f"Average production capacity for all plants: {prod_cap["production_capacity"].mean()}")
# Out:
# Average production capacity for all plants: 446.6666666666667

# %% [markdown]
# Want to combine the `demand` and the `prod_cap` dataframes into one even if their lengths are different. This will make it easier when working with Shiny.

# %%
prod_cap
# Out:
#     production_capacity
# 0                   625
# 1                   250
# 2                   375
# 3                   625
# 4                   125
# ..                  ...
# 70                  375
# 71                  500
# 72                  125
# 73                  750
# 74                  500
#
# [75 rows x 1 columns]

# %%
demand
# Out:
#     demand
# 0      200
# 1       60
# 2      230
# 3      280
# 4       90
# ..     ...
# 120    280
# 121     80
# 122    220
# 123    220
# 124     80
#
# [125 rows x 1 columns]

# %%
eda_df = pd.concat(
    [
        prod_cap,
        demand
    ],
    axis=1
# ).reindex(prod_cap.index)
)
eda_df
# Out:
#      production_capacity demand
# 0                  625.0    200
# 1                  250.0     60
# 2                  375.0    230
# 3                  625.0    280
# 4                  125.0     90
# ..                   ...    ...
# 120                  NaN    280
# 121                  NaN     80
# 122                  NaN    220
# 123                  NaN    220
# 124                  NaN     80
#
# [125 rows x 2 columns]

# %% [markdown]
# Want to confirm the number of "not a numbers" in the production_capacity column.

# %%
count_nan = eda_df['production_capacity'].isnull().sum()
print("Number of NaN values present: " + str(count_nan))
# Out:
# Number of NaN values present: 50

# %% [markdown]
# So the above confirms that the column has the expected number of NaN's.

# %% [markdown]
# The following is a plot using `matplotlib`. Will use ggplot after.

# %%
# Histogram plot
prod_cap.plot(kind='hist', color = 'navy', edgecolor='black', bins=10)
plt.show()

# %%
# Plotting Logic
(
    ggplot(
        prod_cap
        )
    + aes(
        x='production_capacity'
        )
    + geom_histogram(
        bins=10,
        fill='#e06c43',
        color='#040e05'
        )
    + labs(
        title="Production Capacity Distribution",
        x="Production Capacity (units per plant)",
        y="Count (unitless)"
        )
)

# %% [markdown]
# ## Conclusion
#
# So was able to determine some metrics and plots including boxplots and histograms to give an initial view of the synthetic data for the transportation problem.

# %%
# End of "eda.ipynb"
